# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# importing data as pkl 

path=r'/Users/arunibandara/Documents/Achievement4.6_demo_prior'

# %%
path
# Out:
# '/Users/arunibandara/Documents/Achievement4.6_demo_prior'

# %%
 df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02_Data','prepaired_data', 'ords_prods_prior_cor_merged.pkl'))

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices
# 0         195         Soda        77              7     9.0
# ...

# %%
df_new=df_ords_prods_merge[:1000000]

# %%
df_new.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices
# 0         195         Soda        77              7     9.0
# ...

# %%
# Defining the function 

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Appling the function 

df_new['price_range'] = df_new.apply(price_label, axis=1)
# Out:
# /var/folders/7v/5cr9bcbs2zz40rlwm5bw418m0000gq/T/ipykernel_3294/1131398997.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new['price_range'] = df_new.apply(price_label, axis=1)

# %%
df_new['price_range'].value_counts(dropna =False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df_new['prices'].max()
# Out:
# 14.8

# %%
# using loc() function 

df_new.loc[df_new['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# /var/folders/7v/5cr9bcbs2zz40rlwm5bw418m0000gq/T/ipykernel_3294/1191442829.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new.loc[df_new['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_new.loc[(df_new['prices'] <= 15) & (df_new['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_new.loc[df_new['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_new['price_range'].value_counts(dropna =False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices
# 0         195         Soda        77              7     9.0
# ...

# %%
# using loc for whole data frame 

df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <= 15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna =False)
# Out:
# Mid-range product     21890146
# Low-range product     10126384
# High-range product      417682
# Name: price_range_loc, dtype: int64

# %%
# if statement with for loop

df_ords_prods_merge['order_dow'].value_counts(dropna =False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: order_dow, dtype: int64

# %%
df_ords_prods_merge.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords_prods_merge
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32434207   1320836   202557            17                   2
# 32434208     31526   202557            18                   5
# 32434209    758936   203436             1                   2
# 32434210   2745165   203436             2                   3
# 32434211   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     0.0         196
# 1                         7                    15.0         196
# ...

# %%
# if statement with for loop

df_ords_prods_merge['orders_day_of_week'].value_counts(dropna =False)
# Out:
# 0    6209632
# 1    5665830
# 6    4500246
# 2    4217766
# 5    4209449
# 3    3844096
# 4    3787193
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['busiest day']= result

# %%
df_ords_prods_merge['busiest day'].value_counts(dropna =False)
# Out:
# Regularly busy    22437387
# Busiest day        6209632
# Least busy         3787193
# Name: busiest day, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["orders_day_of_week"]:
  if value in[0,1]:
    result.append("Busiest days")
  elif value in [3,4]:
    result.append("Slowest days")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
df_ords_prods_merge['Busiest Days']= result

# %%
df_ords_prods_merge['Busiest Days'].value_counts(dropna =False)

# %% [markdown]
# # The most busiest and most least busiest days are same in the both reuslts , total count of the both are same , therefore this implies the results is giving the same data values in the dataframe.

# %%
# finding out busiest period of the day 
# using loc() function 

df_ords_prods_merge.loc[(df_ords_prods_merge['order_hour_of_day'] >= 9) & (df_ords_prods_merge['order_hour_of_day'] <= 16),'busiest_period_of_day'] = 'Most orders'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_hour_of_day'] >= 0) & (df_ords_prods_merge['order_hour_of_day'] <= 6),'busiest_period_of_day'] = 'Fewest orders'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_hour_of_day'] >= 17) & (df_ords_prods_merge['order_hour_of_day'] <= 23),'busiest_period_of_day'] = 'Average orders'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['order_hour_of_day'] >= 7) & (df_ords_prods_merge['order_hour_of_day'] <= 8),'busiest_period_of_day'] = 'Average orders'

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna =False)

# %%
path=r'/Users/arunibandara/Documents/Achievement 4.7'

# %%
path

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, '02_Data','prepared_data', 'Achievement 4.7-if_statement-corrected.pkl'))
