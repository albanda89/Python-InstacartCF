# %% [markdown]
# # Achievement 4.4-new (corrected)

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path= r'/Users/arunibandara/Documents/Achievement 4.4 - departments'

# %%
path
# Out:
# '/Users/arunibandara/Documents/Achievement 4.4 - departments'

# %%
df_dep=pd.read_csv(os.path.join(path, '02 Data', 'Original data', 'departments.csv'), index_col = False)

# %%
df_dep
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Take the first row of df_dep_t for the header
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# copies over rows beyond the first row
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
# set the headre row as the df header 
df_dep_t_new.columns = new_header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
path=r'/Users/arunibandara/Documents/Achievement 4.3 -Task'

# %%
path
# Out:
# '/Users/arunibandara/Documents/Achievement 4.3 -Task'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods.head(5)
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
df_snacks
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %%
df_snacks_2 = df_prods.loc[df_prods['department_id'] == 19]

# %%
df_snacks_2
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks_3 = df_prods.loc[df_prods['department_id'].isin([19])]

# %%
df_snacks_3
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks_4 = df_prods.loc[df_prods['department_id'].isin([17,18,19])]

# %%
df_snacks_4
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 13             14                 Fresh Scent Dishwasher Cleaner        74
# 14             15                       Overnight Diapers Size 6        56
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# ...           ...                                            ...       ...
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49672       49668                 Apple Cinnamon Scented Candles       101
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
# data wrangling for order.csv 

path=r'/Users/arunibandara/Documents/Achievement 4.3 -Task'

# %%
path
# Out:
# '/Users/arunibandara/Documents/Achievement 4.3 -Task'

# %%
df_orders = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_orders
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 0         2539329        1    prior             1          2
# 1         2398795        1    prior             2          3
# 2          473747        1    prior             3          3
# 3         2254736        1    prior             4          4
# 4          431534        1    prior             5          4
# ...           ...      ...      ...           ...        ...
# 3421078   2266710   206209    prior            10          5
# 3421079   1854736   206209    prior            11          4
# 3421080    626363   206209    prior            12          1
# 3421081   2977660   206209    prior            13          1
# 3421082    272231   206209    train            14          6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
df_orders['user_id'] = df_orders['user_id'].astype('str')

# %%
df_orders['user_id'].dtype
# Out:
# dtype('O')

# %%
df_orders. head()
# Out:
#    order_id user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329       1    prior             1          2                  8
# 1   2398795       1    prior             2          3                  7
# 2    473747       1    prior             3          3                 12
# 3   2254736       1    prior             4          4                  7
# 4    431534       1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df_orders.rename(columns = {'order_dow' : 'order_day_of_week'}, inplace = True)

# %%
df_orders.head()
# Out:
#    order_id user_id eval_set  order_number  order_day_of_week  \
# 0   2539329       1    prior             1                  2
# 1   2398795       1    prior             2                  3
# 2    473747       1    prior             3                  3
# 3   2254736       1    prior             4                  4
# 4    431534       1    prior             5                  4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_orders.describe()
# Out:
#            order_id  order_number  order_day_of_week  order_hour_of_day  \
# count  3.421083e+06  3.421083e+06       3.421083e+06       3.421083e+06
# mean   1.710542e+06  1.715486e+01       2.776219e+00       1.345202e+01
# std    9.875817e+05  1.773316e+01       2.046829e+00       4.226088e+00
# min    1.000000e+00  1.000000e+00       0.000000e+00       0.000000e+00
# 25%    8.552715e+05  5.000000e+00       1.000000e+00       1.000000e+01
# 50%    1.710542e+06  1.100000e+01       3.000000e+00       1.300000e+01
# 75%    2.565812e+06  2.300000e+01       5.000000e+00       1.600000e+01
# max    3.421083e+06  1.000000e+02       6.000000e+00       2.300000e+01
#
#        days_since_prior_order
# count            3.214874e+06
# mean             1.111484e+01
# std              9.206737e+00
# min              0.000000e+00
# 25%              4.000000e+00
# 50%              7.000000e+00
# 75%              1.500000e+01
# max              3.000000e+01

# %%
df_oder_h_1=df_orders[df_orders['order_hour_of_day']==1]

# %%
df_oder_h_1
# Out:
#          order_id user_id eval_set  order_number  order_day_of_week  \
# 536       1354506      37    prior             3                  0
# 604       2019391      42    prior            10                  5
# 815       1630627      54    prior            33                  1
# 889        463436      57    prior             8                  4
# 1465       165754      96    prior            11                  0
# ...           ...     ...      ...           ...                ...
# 3419291   2503515  206097    prior             5                  0
# 3419337    602757  206102    prior             3                  6
# 3420361    168787  206165    prior            21                  6
# 3420363   1145289  206165    prior            23                  0
# 3420857   1951515  206200    prior            19                  1
#
#          order_hour_of_day  days_since_prior_order
# 536                      1                     8.0
# ...

# %%
df_oder_h_1.shape
# Out:
# (12398, 7)

# %%
df_oder_h_2=df_orders[df_orders['order_hour_of_day']==2]

# %%
df_oder_h_2.shape
# Out:
# (7539, 7)

# %%
df_oder_h_3=df_orders[df_orders['order_hour_of_day']==3]

# %%
df_oder_h_3.shape
# Out:
# (5474, 7)

# %%
df_oder_h_4=df_orders[df_orders['order_hour_of_day']==4]

# %%
df_oder_h_4.shape
# Out:
# (5527, 7)

# %%
df_oder_h_5=df_orders[df_orders['order_hour_of_day']==5]

# %%
df_oder_h_5.shape
# Out:
# (9569, 7)

# %%
df_oder_h_6=df_orders[df_orders['order_hour_of_day']==6]

# %%
df_oder_h_6.shape
# Out:
# (30529, 7)

# %%
df_oder_h_7=df_orders[df_orders['order_hour_of_day']==7]

# %%
df_oder_h_7.shape
# Out:
# (91868, 7)

# %%
df_oder_h_8=df_orders[df_orders['order_hour_of_day']==8]

# %%
df_oder_h_8.shape
# Out:
# (178201, 7)

# %%
df_oder_h_9=df_orders[df_orders['order_hour_of_day']==9]

# %%
df_oder_h_9.shape
# Out:
# (257812, 7)

# %%
df_oder_h_10=df_orders[df_orders['order_hour_of_day']==10]

# %%
df_oder_h_10.shape
# Out:
# (288418, 7)

# %%
df_oder_h_11=df_orders[df_orders['order_hour_of_day']==11]

# %%
df_oder_h_11.shape
# Out:
# (284728, 7)

# %%
df_oder_h_12=df_orders[df_orders['order_hour_of_day']==12]

# %%
df_oder_h_12.shape
# Out:
# (272841, 7)

# %%
df_oder_h_13=df_orders[df_orders['order_hour_of_day']==13]

# %%
df_oder_h_13.shape
# Out:
# (277999, 7)

# %%
df_oder_h_14=df_orders[df_orders['order_hour_of_day']==14]

# %%
df_oder_h_14.shape
# Out:
# (283042, 7)

# %%
df_oder_h_15=df_orders[df_orders['order_hour_of_day']==15]

# %%
df_oder_h_15.shape
# Out:
# (283639, 7)

# %%
df_oder_h_16=df_orders[df_orders['order_hour_of_day']==16]

# %%
df_oder_h_16.shape
# Out:
# (272553, 7)

# %%
df_oder_h_17=df_orders[df_orders['order_hour_of_day']==17]

# %%
df_oder_h_17.shape
# Out:
# (228795, 7)

# %%
df_oder_h_18=df_orders[df_orders['order_hour_of_day']==18]

# %%
df_oder_h_18.shape
# Out:
# (182912, 7)

# %%
df_oder_h_19=df_orders[df_orders['order_hour_of_day']==19]

# %%
df_oder_h_19.shape
# Out:
# (140569, 7)

# %%
df_oder_h_20=df_orders[df_orders['order_hour_of_day']==20]

# %%
df_oder_h_20.shape
# Out:
# (104292, 7)

# %%
df_oder_h_21=df_orders[df_orders['order_hour_of_day']==21]

# %%
df_oder_h_21.shape
# Out:
# (78109, 7)

# %%
df_oder_h_22=df_orders[df_orders['order_hour_of_day']==22]

# %%
df_oder_h_22.shape
# Out:
# (61468, 7)

# %%
df_oder_h_23=df_orders[df_orders['order_hour_of_day']==23]

# %%
df_oder_h_23.shape
# Out:
# (40043, 7)

# %%
# this shows that the total hours of the day are 23  and among them, the highest frequency occurs in 10 th hour which means 10 -11 is the highest orders and therefore this hour is the busiest hour

# %%
# data wwrangling for product csv

data_dict = df_dep_t_new.to_dict('index')

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_prods['department_id']==4
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_produce_4= df_prods[df_prods['department_id']==4]

# %%
df_produce_4
# Out:
#        product_id                                      product_name  aisle_id  \
# 30             31                                White Pearl Onions       123
# 42             43                               Organic Clementines       123
# 44             45                                 European Cucumber        83
# 65             66                         European Style Spring Mix       123
# 88             89                    Yogurt Fruit Dip Sliced Apples       123
# ...           ...                                               ...       ...
# 49582       49578                                Black Garlic Bulbs       123
# 49623       49619                                        Opo Squash        83
# 49639       49635  Baby Food Blueberry, Parsnip & Buckwheat Stage 2        83
# 49661       49657                                 Cabernet Tomatoes        83
# 49687       49683                                    Cucumber Kirby        83
#
#        department_id  prices
# ...

# %%
# department_id  4 indicates the production department (produce) and there are 1684 values indicated in department_id 4

# %%
print(data_dict.get('14'))
# Out:
# {'department': 'breakfast'}

# %%
df_breakfast=df_prods[df_prods['department_id']==14]

# %%
df_breakfast
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
# According to data dictionary  alcohol, deli, beverages, and meat/seafood depatments department_id as follows 5,20,7,12

# %%
df_party_all = df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]

# %%
df_party_all
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
# yes because it makes you assure the accuracy, also help to conduct different analytical tasks only on those filtered subset dataframe and saving time and decreasing the load on your computer. last data frame is 7650rows

# %%
df_orders
# Out:
#          order_id user_id eval_set  order_number  order_day_of_week  \
# 0         2539329       1    prior             1                  2
# 1         2398795       1    prior             2                  3
# 2          473747       1    prior             3                  3
# 3         2254736       1    prior             4                  4
# 4          431534       1    prior             5                  4
# ...           ...     ...      ...           ...                ...
# 3421078   2266710  206209    prior            10                  5
# 3421079   1854736  206209    prior            11                  4
# 3421080    626363  206209    prior            12                  1
# 3421081   2977660  206209    prior            13                  1
# 3421082    272231  206209    train            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49688       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49689       49685                 En Croute Roast Hazelnut Cranberry
# 49690       49686                                   Artisan Baguette
# 49691       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49692       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %%
df_orders
# Out:
#          order_id user_id eval_set  order_number  order_day_of_week  \
# 0         2539329       1    prior             1                  2
# 1         2398795       1    prior             2                  3
# 2          473747       1    prior             3                  3
# 3         2254736       1    prior             4                  4
# 4          431534       1    prior             5                  4
# ...           ...     ...      ...           ...                ...
# 3421078   2266710  206209    prior            10                  5
# 3421079   1854736  206209    prior            11                  4
# 3421080    626363  206209    prior            12                  1
# 3421081   2977660  206209    prior            13                  1
# 3421082    272231  206209    train            14                  6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
df_user_id_1=df_orders[df_orders['user_id']=='1']

# %%
df_user_id_1
# Out:
#     order_id user_id eval_set  order_number  order_day_of_week  \
# 0    2539329       1    prior             1                  2
# 1    2398795       1    prior             2                  3
# 2     473747       1    prior             3                  3
# 3    2254736       1    prior             4                  4
# 4     431534       1    prior             5                  4
# 5    3367565       1    prior             6                  2
# 6     550135       1    prior             7                  1
# 7    3108588       1    prior             8                  1
# 8    2295261       1    prior             9                  1
# 9    2550362       1    prior            10                  4
# 10   1187899       1    train            11                  4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %%
df_user_id_1.describe()
# Out:
#            order_id  order_number  order_day_of_week  order_hour_of_day  \
# count  1.100000e+01     11.000000          11.000000          11.000000
# mean   1.923450e+06      6.000000           2.636364          10.090909
# std    1.071950e+06      3.316625           1.286291           3.477198
# min    4.315340e+05      1.000000           1.000000           7.000000
# 25%    8.690170e+05      3.500000           1.500000           7.500000
# 50%    2.295261e+06      6.000000           3.000000           8.000000
# 75%    2.544846e+06      8.500000           4.000000          13.000000
# max    3.367565e+06     11.000000           4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# every satat describe in the user_id subset is 1.0. so its not a distribution just a point value.

# %%
# Exporting final dataframe orders and products and departments 

path=r'/Users/arunibandara/Documents/Achievement4.4-new'

# %%
path
# Out:
# '/Users/arunibandara/Documents/Achievement4.4-new'

# %%
df_orders.to_csv(os.path.join(path, '02 Data','prepared_data', 'ords_wrangled_new1.csv'))

# %%
df_prods.to_csv(os.path.join(path, '02 Data','prepared_data', 'prods_wrangled_new1.csv'))

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','prepared_data', 'department_wrangled_new1.csv'))
