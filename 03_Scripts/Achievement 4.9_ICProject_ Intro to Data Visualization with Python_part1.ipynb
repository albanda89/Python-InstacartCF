# %%
# Import Libraries 

import pandas as pd
import numpy as np
import os

# %%
# Import customer data

path=r'/Users/arunibandara/Documents/Achievement4.9'

# %%
path
# Out:
# '/Users/arunibandara/Documents/Achievement4.9'

# %%
df_customer=pd.read_csv(os.path.join(path, '02_Data', 'original_data', 'customers.csv'), index_col = False)

# %%
df_customer
# Out:
#         user_id First Name    Surnam  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %%
df_customer.shape
# Out:
# (206209, 10)

# %%
# wrangling data -renaming column droping unwanted column

df_customer.drop(columns = ['Surnam'])
# Out:
#         user_id First Name  Gender           STATE  Age date_joined  \
# 0         26711    Deborah  Female        Missouri   48    1/1/2017
# 1         33890   Patricia  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Male           Idaho   35    1/1/2017
# 3        125935   Michelle  Female            Iowa   40    1/1/2017
# 4        130797        Ann  Female        Maryland   26    1/1/2017
# ...         ...        ...     ...             ...  ...         ...
# 206204   168073       Lisa  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Female        Missouri   66    4/1/2020
# 206207    81095       Rose  Female      California   27    4/1/2020
# 206208    80148    Cynthia  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 0                  3    married  165665
# 1                  0     single   59285
# ...

# %%
# finding missing values 

df_customer.isnull().sum()
# Out:
# user_id             0
# First Name      11259
# Surnam              0
# Gender              0
# STATE               0
# Age                 0
# date_joined         0
# n_dependants        0
# fam_status          0
# income              0
# dtype: int64

# %%
# First name column is with missing values and not neccesary for analysis so will drop the column 

df_customer = df_customer.drop(columns = ['First Name'])

# %%
df_customer
# Out:
#         user_id    Surnam  Gender           STATE  Age date_joined  \
# 0         26711  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Farley    Male           Idaho   35    1/1/2017
# 3        125935     Hicks  Female            Iowa   40    1/1/2017
# 4        130797   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...       ...     ...             ...  ...         ...
# 206204   168073      Case  Female  North Carolina   44    4/1/2020
# 206205    49635   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095   Rollins  Female      California   27    4/1/2020
# 206208    80148     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 0                  3    married  165665
# 1                  0     single   59285
# ...

# %%
# renaming column

df_customer.rename(columns = {'Surnam' : 'surname'}, inplace = True)

# %%
df_customer
# Out:
#         user_id   surname  Gender           STATE  Age date_joined  \
# 0         26711  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Farley    Male           Idaho   35    1/1/2017
# 3        125935     Hicks  Female            Iowa   40    1/1/2017
# 4        130797   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...       ...     ...             ...  ...         ...
# 206204   168073      Case  Female  North Carolina   44    4/1/2020
# 206205    49635   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095   Rollins  Female      California   27    4/1/2020
# 206208    80148     Noble  Female        New York   55    4/1/2020
#
#         n_dependants fam_status  income
# 0                  3    married  165665
# 1                  0     single   59285
# ...

# %%
df_customer = df_customer.drop(columns = ['surname'])

# %%
df_customer
# Out:
#         user_id  Gender           STATE  Age date_joined  n_dependants  \
# 0         26711  Female        Missouri   48    1/1/2017             3
# 1         33890  Female      New Mexico   36    1/1/2017             0
# 2         65803    Male           Idaho   35    1/1/2017             2
# 3        125935  Female            Iowa   40    1/1/2017             0
# 4        130797  Female        Maryland   26    1/1/2017             1
# ...         ...     ...             ...  ...         ...           ...
# 206204   168073  Female  North Carolina   44    4/1/2020             1
# 206205    49635    Male          Hawaii   62    4/1/2020             3
# 206206   135902  Female        Missouri   66    4/1/2020             2
# 206207    81095  Female      California   27    4/1/2020             1
# 206208    80148  Female        New York   55    4/1/2020             1
#
#        fam_status  income
# 0         married  165665
# 1          single   59285
# 2         married   99568
# ...

# %%
# renaming column

df_customer.rename(columns = {'Gender' : 'gender', 'STATE' : 'state','Age' : 'age','n_dependants' : 'number_dependants', 'fam_status' : 'family_status'}, inplace = True)

# %%
df_customer
# Out:
#         user_id  gender           state  age date_joined  number_dependants  \
# 0         26711  Female        Missouri   48    1/1/2017                  3
# 1         33890  Female      New Mexico   36    1/1/2017                  0
# 2         65803    Male           Idaho   35    1/1/2017                  2
# 3        125935  Female            Iowa   40    1/1/2017                  0
# 4        130797  Female        Maryland   26    1/1/2017                  1
# ...         ...     ...             ...  ...         ...                ...
# 206204   168073  Female  North Carolina   44    4/1/2020                  1
# 206205    49635    Male          Hawaii   62    4/1/2020                  3
# 206206   135902  Female        Missouri   66    4/1/2020                  2
# 206207    81095  Female      California   27    4/1/2020                  1
# 206208    80148  Female        New York   55    4/1/2020                  1
#
#        family_status  income
# ...

# %%
# Checking data type for user_id column 

df_customer['user_id'].dtype
# Out:
# dtype('int64')

# %%
# Changing a variable's data type

df_customer['user_id'] = df_customer['user_id'].astype('str')

df_customer['user_id'].dtype
# Out:
# dtype('O')

# %%
# Data Consistency Checks- satistica data

df_customer.describe()
# Out:
#                  age  number_dependants         income
# count  206209.000000      206209.000000  206209.000000
# mean       49.501646           1.499823   94632.852548
# std        18.480962           1.118433   42473.786988
# min        18.000000           0.000000   25903.000000
# 25%        33.000000           0.000000   59874.000000
# 50%        49.000000           1.000000   93547.000000
# 75%        66.000000           3.000000  124244.000000
# max        81.000000           3.000000  593901.000000

# %%
# all counts same 
# All data seems correct

# %%
# finding Duplicate values 

df_customer[df_customer.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, date_joined, number_dependants, family_status, income]
# Index: []

# %%
# Seems no data duplication

# %%
df_customer.shape
# Out:
# (206209, 8)

# %%
# Checking for mixed type data

for col in df_customer.columns.tolist():
  weird = (df_customer[[col]].applymap(type) != df_customer[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_customer[weird]) > 0:
    print (col)

# %%
# it indicates that customer data set is not a mixed type data

# %%
# Merging datasets-  dataframe and customer dataframe

# %%
# importing ords_prods_merge as a csv

path=r'/Users/arunibandara/Documents/Achievement 4.8 -Task '

df_ords_prods_merge = pd.read_pickle(os.path.join(path,'02_Data','prepaired_data','Achievement 4.8 -Task _new 1.pkl'))

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0 product_name  aisle_id  department_id  prices  max_order  \
# ...

# %%
df_ords_prods_merge['user_id'].dtype
# Out:
# dtype('int64')

# %%
df_ords_prods_merge['user_id'] = df_ords_prods_merge['user_id'].astype('str')

# %%
df_ords_prods_merge['user_id'].dtype
# Out:
# dtype('O')

# %%
df_customer.head()
# Out:
#   user_id  gender       state  age date_joined  number_dependants  \
# 0   26711  Female    Missouri   48    1/1/2017                  3
# 1   33890  Female  New Mexico   36    1/1/2017                  0
# 2   65803    Male       Idaho   35    1/1/2017                  2
# 3  125935  Female        Iowa   40    1/1/2017                  0
# 4  130797  Female    Maryland   26    1/1/2017                  1
#
#   family_status  income
# 0       married  165665
# 1        single   59285
# 2       married   99568
# 3        single   42049
# 4       married   40374

# %%
df_customer['user_id'].dtype
# Out:
# dtype('O')

# %%
df_ords_prods_custm_merged = pd.merge(df_ords_prods_merge, df_customer, on = 'user_id', how = 'outer')

# %%
df_ords_prods_custm_merged.head(10)
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
# 5   3367565       1             6                   2                  7
# 6    550135       1             7                   1                  9
# 7   3108588       1             8                   1                 14
# 8   2295261       1             9                   1                 16
# 9   2550362       1            10                   4                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# ...

# %%
path=r'/Users/arunibandara/Documents/Achievement4.9'

df_ords_prods_custm_merged.to_pickle(os.path.join(path,'02_Data','prepared_data','Achievement4.9-Task_part1.pkl'))

# %%
df_ords_prods_custm_merged.head()
# Out:
#    order_id user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329       1             1                   2                  8
# 1   2398795       1             2                   3                  7
# 2    473747       1             3                   3                 12
# 3   2254736       1             4                   4                  7
# 4    431534       1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     0.0         196                  1          0
# 1                    15.0         196                  1          1
# 2                    21.0         196                  1          1
# 3                    29.0         196                  1          1
# 4                    28.0         196                  1          1
#
#    Unnamed: 0  ... spending_flag  median_days         frequency_flag  gender  \
# ...

# %%
df_ords_prods_custm_merged.shape
# Out:
# (32434212, 27)
